# %% [markdown]
# # Вероятности
# ### Борунов Семён Сергеевич НММбд01-22

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm, uniform

# %% [markdown]
# ### Задача 5
#
# Для всех ~~предыдущих~~ последующих задач вычислите среднее, дисперсию и 0.25 и 0.9 квантили.
#
# Для всех ~~предыдущих~~ последующих задач постройте графики cdf и pdf.

# %%
def print_stats(distr):
    mean, var = distr.stats(moments='mv')
    print(f'M(X) = {mean}, D(X) = {var} \n0.25 квантиль: {distr.ppf(0.25)}\n0.9 квантиль: {distr.ppf(0.9)}')

# %% [markdown]
# ### Задача 1
#
# Случайная величина ошибки взвешивания распределена по нормальному закону с нулевым математическим ожиданием и стандартным отклонением 4 грамма. Найти вероятность того, что очередное взвешивание будет проведено с ошибкой, не превышающей по модулю 6 граммов.

# %% [markdown]
# $$M = 0, \sigma = 4, \epsilon = 6  \\
# P(|X- M| < \epsilon) = F(\epsilon) - F(-\epsilon)$$

# %%
mass = norm(loc=0, scale=4)
mass.cdf(6) - mass.cdf(-6)
# Out:
# 0.8663855974622838

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(9, 4))
x = np.linspace(-10, 10, 100)
ax1.plot(x, mass.pdf(x))
ax1.set_title('Плотность распределения, f(x)')
ax2.plot(x, mass.cdf(x))
ax2.set_title('Функция распределения, F(x)')
# Out:
# Text(0.5, 1.0, 'Функция распределения, F(x)')

# %%
print_stats(mass)
# Out:
# M(X) = 0.0, D(X) = 16.0
# 0.25 квантиль: -2.697959000784327
# 0.9 квантиль: 5.1262062621784015

# %% [markdown]
# ### Задача 2
#
# Автобусы некоторого маршрута идут строго по расписанию и интервалом 5 минут. Составьте функцию плотности случайной величины X – времени ожидании очередного автобуса пассажиром, который наугад подошёл к остановке. Найдите вероятность того, что он будет ждать автобус не более 2 минут.

# %%
time = uniform(0, 5)
time.cdf(2) - time.cdf(0)
# Out:
# 0.4

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(9, 4))
x = np.linspace(-2, 7, 100)
ax1.plot(x, time.pdf(x))
ax1.set_title('Плотность распределения, f(x)')
ax2.plot(x, time.cdf(x))
ax2.set_title('Функция распределения, F(x)')
# Out:
# Text(0.5, 1.0, 'Функция распределения, F(x)')

# %%
print_stats(time)
# Out:
# M(X) = 2.5, D(X) = 2.083333333333333
# 0.25 квантиль: 1.25
# 0.9 квантиль: 4.5

# %% [markdown]
# ### Задача 3
#
# Рост мальчиков возрастной группы 15 лет есть нормально распределённая случайная величина X с математическим ожиданием роста 161 см и среднеквадратичным отклонением 4 см. Какую долю костюмов для мальчиков, имеющих рост от 152 до 158 см, нужно предусмотреть в объёме производства для данной возрастной группы?

# %%
height = norm(loc=161, scale=4)
height.cdf(158) - height.cdf(152)
# Out:
# 0.2144028797218235

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(9, 4))
x = np.linspace(150, 170, 100)
ax1.plot(x, height.pdf(x))
ax1.set_title('Плотность распределения, f(x)')
ax2.plot(x, height.cdf(x))
ax2.set_title('Функция распределения, F(x)')
# Out:
# Text(0.5, 1.0, 'Функция распределения, F(x)')

# %% [markdown]
# ### Задача 4
#
# На машиностроительном заводе в процессе производства за неделю обнаруживается в среднем 100 бракованных деталей со среднеквадричным отклонением в 12 деталей. Рассчитайте следующее: 1) вероятность того, что за неделю будет 20-30 бракованных деталей, 2) вероятность того, что за день будет хотя бы одна забракованная деталь.

# %%
broken = norm(loc=100, scale=12)

broken.cdf(30) - broken.cdf(20)
# Out:
# 2.7034598124020633e-09

# %% [markdown]
# даже 30 бракованных деталей уходит за 3$\sigma$ поэтому логично, что вышел почти 0

# %%
1 - broken.cdf(0)/7
# Out:
# 1.0

# %% [markdown]
# Т. е. брак будет почти навярняка

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(9, 4))
x = np.linspace(50, 150, 100)
ax1.plot(x, broken.pdf(x))
ax1.set_title('Плотность распределения, f(x)')
ax2.plot(x, broken.cdf(x))
ax2.set_title('Функция распределения, F(x)')
# Out:
# Text(0.5, 1.0, 'Функция распределения, F(x)')

# %%
print_stats(broken)
# Out:
# M(X) = 100.0, D(X) = 144.0
# 0.25 квантиль: 91.90612299764702
# 0.9 квантиль: 115.3786187865352
